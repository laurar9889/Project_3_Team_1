# %%
#Import dependencies
import csv
import matplotlib as plt
import pandas as pd
from pathlib import Path
import numpy as np

csvpath = Path('.', 'Resources', 'births-attended-by-skilled-health-personnel.csv')

# %%
# Read the CSV into a Pandas DataFrame
skilled_personnel_df = pd.read_csv(csvpath, low_memory=False)

# Print the first rows of data to the screen
skilled_personnel_df.head()
# Out:
#     IndicatorCode                                        Indicator ValueType  \
# 0  MDG_0000000025  Births attended by skilled health personnel (%)      text
# 1  MDG_0000000025  Births attended by skilled health personnel (%)      text
# 2  MDG_0000000025  Births attended by skilled health personnel (%)      text
# 3  MDG_0000000025  Births attended by skilled health personnel (%)      text
# 4  MDG_0000000025  Births attended by skilled health personnel (%)      text
#
#   ParentLocationCode         ParentLocation Location type SpatialDimValueCode  \
# 0               SEAR        South-East Asia       Country                 IDN
# 1                EUR                 Europe       Country                 FRA
# 2                EMR  Eastern Mediterranean       Country                 SAU
# 3                EMR  Eastern Mediterranean       Country                 JOR
# 4                EMR  Eastern Mediterranean       Country                 YEM
#
#        Location Period type     Period  ...  FactValueUoM  \
# 0     Indonesia        Year       2023  ...           NaN
# 1        France        Year       2023  ...           NaN
# 2  Saudi Arabia        Year       2023  ...           NaN
# 3        Jordan        Year       2023  ...           NaN
# 4         Yemen        Year  2022-2023  ...           NaN
#
#    FactValueNumericLowPrefix  FactValueNumericLow  FactValueNumericHighPrefix  \
# 0                        NaN                  NaN                         NaN
# 1                        NaN                  NaN                         NaN
# 2                        NaN                  NaN                         NaN
# 3                        NaN                  NaN                         NaN
# 4                        NaN                  NaN                         NaN
#
#    FactValueNumericHigh  Value  FactValueTranslationID  \
# 0                   NaN   95.7                     NaN
# 1                   NaN   97.6                     NaN
# 2                   NaN   99.8                     NaN
# 3                   NaN   99.9                     NaN
# 4                   NaN   60.9                     NaN
#
#                                         FactComments  Language  \
# 0    SUSENAS 2023 as part of Welfare Statistics 2023        EN
# 1  Institutional Birth (IB): includes all deliver...        EN
# 2               Women Health and Reproductive Survey        EN
# 3  Department of Statistics (DoS) [Jordan] and IC...        EN
# 4  Central Statistical Organization (CSO) and Uni...        EN
#
#           DateModified
# 0  2024-04-26 00:00:00
# 1  2024-04-26 00:00:00
# 2  2024-04-26 00:00:00
# 3  2024-04-26 00:00:00
# 4  2024-04-26 00:00:00
#
# [5 rows x 34 columns]

# %%
#make a copy of dataframe and drop unwanted columns
clean_df_skilled_personnel = skilled_personnel_df.drop(['Indicator','FactValueUoM', 'FactValueNumericLowPrefix',
                                                        'FactValueNumericPrefix','FactValueNumericLow','FactValueTranslationID', 'Dim2', 'Dim2 type', 'Dim1 type',
                                                        'Dim2ValueCode', 'Dim3', 'DataSourceDimValueCode', 'Dim3ValueCode', 'DataSource', 'Dim1ValueCode', 'Dim3 type',
                                                        'Dim1', 'FactValueNumericHighPrefix', 'FactValueNumericHigh'], axis=1)
clean_df_skilled_personnel.head()
# Out:
#     IndicatorCode ValueType ParentLocationCode         ParentLocation  \
# 0  MDG_0000000025      text               SEAR        South-East Asia
# 1  MDG_0000000025      text                EUR                 Europe
# 2  MDG_0000000025      text                EMR  Eastern Mediterranean
# 3  MDG_0000000025      text                EMR  Eastern Mediterranean
# 4  MDG_0000000025      text                EMR  Eastern Mediterranean
#
#   Location type SpatialDimValueCode      Location Period type     Period  \
# 0       Country                 IDN     Indonesia        Year       2023
# 1       Country                 FRA        France        Year       2023
# 2       Country                 SAU  Saudi Arabia        Year       2023
# 3       Country                 JOR        Jordan        Year       2023
# 4       Country                 YEM         Yemen        Year  2022-2023
#
#    IsLatestYear  FactValueNumeric  Value  \
# 0          True              95.7   95.7
# 1          True              97.6   97.6
# 2          True              99.8   99.8
# 3          True              99.9   99.9
# 4          True              60.9   60.9
#
#                                         FactComments Language  \
# 0    SUSENAS 2023 as part of Welfare Statistics 2023       EN
# 1  Institutional Birth (IB): includes all deliver...       EN
# 2               Women Health and Reproductive Survey       EN
# 3  Department of Statistics (DoS) [Jordan] and IC...       EN
# 4  Central Statistical Organization (CSO) and Uni...       EN
#
#           DateModified
# 0  2024-04-26 00:00:00
# 1  2024-04-26 00:00:00
# 2  2024-04-26 00:00:00
# 3  2024-04-26 00:00:00
# 4  2024-04-26 00:00:00

# %%
parent_location = clean_df_skilled_personnel.groupby(["ParentLocation"])["Value"].value_counts()
pd.DataFrame(parent_location)
# Out:
#                        count
# ParentLocation  Value
# Africa          99.8      12
#                 99.0       8
#                 99.7       8
#                 99.5       6
#                 43.7       3
# ...                      ...
# Western Pacific 97.5       1
#                 97.6       1
#                 97.8       1
#                 98.2       1
#                 98.9       1
#
# [745 rows x 1 columns]
