# %%
#importing Pandas dataframe
import pandas as pd
from importlib import resources

# %% [markdown]
# Importing Data Source

# %%
#importing Raw-data 
df = pd.read_csv('Resources\Modern Family Planning_Raw data.csv')
df.head(10)
# Out:
#   IndicatorCode                                          Indicator ValueType  \
# 0      SDGFPALL  Women of reproductive age (aged 15-49 years) w...      text
# 1      SDGFPALL  Women of reproductive age (aged 15-49 years) w...      text
# 2      SDGFPALL  Women of reproductive age (aged 15-49 years) w...      text
# 3      SDGFPALL  Women of reproductive age (aged 15-49 years) w...      text
# 4      SDGFPALL  Women of reproductive age (aged 15-49 years) w...      text
# 5      SDGFPALL  Women of reproductive age (aged 15-49 years) w...      text
# 6      SDGFPALL  Women of reproductive age (aged 15-49 years) w...      text
# 7      SDGFPALL  Women of reproductive age (aged 15-49 years) w...      text
# 8      SDGFPALL  Women of reproductive age (aged 15-49 years) w...      text
# 9      SDGFPALL  Women of reproductive age (aged 15-49 years) w...      text
#
#   ParentLocationCode   ParentLocation Location type SpatialDimValueCode  \
# 0                AFR           Africa       Country                 UGA
# 1                AFR           Africa       Country                 NER
# 2                AFR           Africa       Country                 BFA
# 3                WPR  Western Pacific       Country                 VNM
# 4                AFR           Africa       Country                 CIV
# 5                EUR           Europe       Country                 MDA
# 6                AFR           Africa       Country                 ETH
# 7                AFR           Africa       Country                 MDG
# 8                AMR         Americas       Country                 PER
# 9                AFR           Africa       Country                 KEN
#
#               Location Period type     Period  ...  FactValueUoM  \
# 0               Uganda        Year       2021  ...           NaN
# 1                Niger        Year  2020-2021  ...           NaN
# 2         Burkina Faso        Year  2020-2021  ...           NaN
# 3             Viet Nam        Year  2020-2021  ...           NaN
# 4        Cote d'Ivoire        Year       2020  ...           NaN
# 5  Republic of Moldova        Year       2020  ...           NaN
# 6             Ethiopia        Year       2020  ...           NaN
# 7           Madagascar        Year       2020  ...           NaN
# 8                 Peru        Year       2020  ...           NaN
# 9                Kenya        Year       2020  ...           NaN
#
#   FactValueNumericLowPrefix FactValueNumericLow FactValueNumericHighPrefix  \
# 0                       NaN                 NaN                        NaN
# 1                       NaN                 NaN                        NaN
# 2                       NaN                 NaN                        NaN
# 3                       NaN                 NaN                        NaN
# 4                       NaN                 NaN                        NaN
# 5                       NaN                 NaN                        NaN
# 6                       NaN                 NaN                        NaN
# 7                       NaN                 NaN                        NaN
# 8                       NaN                 NaN                        NaN
# 9                       NaN                 NaN                        NaN
#
#   FactValueNumericHigh Value FactValueTranslationID  \
# 0                  NaN  65.5                    NaN
# 1                  NaN  36.9                    NaN
# 2                  NaN  58.2                    NaN
# 3                  NaN  72.1                    NaN
# 4                  NaN  46.1                    NaN
# 5                  NaN  59.5                    NaN
# 6                  NaN  62.6                    NaN
# 7                  NaN  65.6                    NaN
# 8                  NaN  65.9                    NaN
# 9                  NaN  77.1                    NaN
#
#                                         FactComments  Language  \
# 0  The global indicator represents all women of r...        EN
# 1                      Niger 2021 PMA Survey Phase 1        EN
# 2               Burkina Faso 2021 PMA Survey Phase 2        EN
# 3  The global indicator represents all women of r...        EN
# 4              Côte d'Ivoire 2020 PMA Survey Phase 1        EN
# 5         Moldova 2020 Gender and Generations Survey        EN
# 6  The global indicator represents all women of r...        EN
# 7  The global indicator represents all women of r...        EN
# 8  The global indicator represents all women of r...        EN
# 9                      Kenya 2020 PMA Survey Phase 2        EN
#
#                DateModified
# 0  2023-03-08T05:00:00.000Z
# 1  2023-03-08T05:00:00.000Z
# 2  2023-03-08T05:00:00.000Z
# 3  2023-03-08T05:00:00.000Z
# 4  2023-03-08T05:00:00.000Z
# 5  2023-03-08T05:00:00.000Z
# 6  2023-03-08T05:00:00.000Z
# 7  2023-03-08T05:00:00.000Z
# 8  2023-03-08T05:00:00.000Z
# 9  2023-03-08T05:00:00.000Z
#
# [10 rows x 34 columns]

# %% [markdown]
# DATA Cleaning

# %%
#checking numbers of Columns
df.columns
# Out:
# Index(['IndicatorCode', 'Indicator', 'ValueType', 'ParentLocationCode',
#        'ParentLocation', 'Location type', 'SpatialDimValueCode', 'Location',
#        'Period type', 'Period', 'IsLatestYear', 'Dim1 type', 'Dim1',
#        'Dim1ValueCode', 'Dim2 type', 'Dim2', 'Dim2ValueCode', 'Dim3 type',
#        'Dim3', 'Dim3ValueCode', 'DataSourceDimValueCode', 'DataSource',
#        'FactValueNumericPrefix', 'FactValueNumeric', 'FactValueUoM',
#        'FactValueNumericLowPrefix', 'FactValueNumericLow',
#        'FactValueNumericHighPrefix', 'FactValueNumericHigh', 'Value',
#        'FactValueTranslationID', 'FactComments', 'Language', 'DateModified'],
#       dtype='object')

# %% [markdown]
# Dropping unnecessary data

# %%
#removing unnecessery columns 
drop_colums = df.drop(['ValueType','Location type','Period type','Dim1 type','IsLatestYear','Dim1ValueCode','Dim2 type','Dim2ValueCode',
         'Dim3 type', 'Dim3', 'Dim3ValueCode','DataSourceDimValueCode', 'DataSource','FactValueNumericPrefix','FactValueUoM',
          'FactValueTranslationID', 'FactValueNumericHigh','FactValueNumericHighPrefix','FactValueNumericLow',
         'FactValueNumericLowPrefix','DateModified'], axis=1)

# %%
drop_colums.head(10)
# Out:
#   IndicatorCode                                          Indicator  \
# 0      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 1      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 2      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 3      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 5      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 6      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 7      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 8      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 9      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#   ParentLocationCode   ParentLocation SpatialDimValueCode  \
# 0                AFR           Africa                 UGA
# 1                AFR           Africa                 NER
# 2                AFR           Africa                 BFA
# 3                WPR  Western Pacific                 VNM
# 4                AFR           Africa                 CIV
# 5                EUR           Europe                 MDA
# 6                AFR           Africa                 ETH
# 7                AFR           Africa                 MDG
# 8                AMR         Americas                 PER
# 9                AFR           Africa                 KEN
#
#               Location     Period    Dim1         Dim2  FactValueNumeric  \
# 0               Uganda       2021  Female  15-49 years              65.5
# 1                Niger  2020-2021  Female  15-49 years              36.9
# 2         Burkina Faso  2020-2021  Female  15-49 years              58.2
# 3             Viet Nam  2020-2021  Female  15-49 years              72.1
# 4        Cote d'Ivoire       2020  Female  15-49 years              46.1
# 5  Republic of Moldova       2020  Female  15-49 years              59.5
# 6             Ethiopia       2020  Female  15-49 years              62.6
# 7           Madagascar       2020  Female  15-49 years              65.6
# 8                 Peru       2020  Female  15-49 years              65.9
# 9                Kenya       2020  Female  15-49 years              77.1
#
#    Value                                       FactComments Language
# 0   65.5  The global indicator represents all women of r...       EN
# 1   36.9                      Niger 2021 PMA Survey Phase 1       EN
# 2   58.2               Burkina Faso 2021 PMA Survey Phase 2       EN
# 3   72.1  The global indicator represents all women of r...       EN
# 4   46.1              Côte d'Ivoire 2020 PMA Survey Phase 1       EN
# 5   59.5         Moldova 2020 Gender and Generations Survey       EN
# 6   62.6  The global indicator represents all women of r...       EN
# 7   65.6  The global indicator represents all women of r...       EN
# 8   65.9  The global indicator represents all women of r...       EN
# 9   77.1                      Kenya 2020 PMA Survey Phase 2       EN

# %% [markdown]
# Removing Duplicates

# %%
#Removing duplicate column
Cleaned_Data = drop_colums.drop(['FactValueNumeric'], axis=1)

# %%
Cleaned_Data.head(5)
# Out:
#   IndicatorCode                                          Indicator  \
# 0      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 1      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 2      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 3      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#   ParentLocationCode   ParentLocation SpatialDimValueCode       Location  \
# 0                AFR           Africa                 UGA         Uganda
# 1                AFR           Africa                 NER          Niger
# 2                AFR           Africa                 BFA   Burkina Faso
# 3                WPR  Western Pacific                 VNM       Viet Nam
# 4                AFR           Africa                 CIV  Cote d'Ivoire
#
#       Period    Dim1         Dim2  Value  \
# 0       2021  Female  15-49 years   65.5
# 1  2020-2021  Female  15-49 years   36.9
# 2  2020-2021  Female  15-49 years   58.2
# 3  2020-2021  Female  15-49 years   72.1
# 4       2020  Female  15-49 years   46.1
#
#                                         FactComments Language
# 0  The global indicator represents all women of r...       EN
# 1                      Niger 2021 PMA Survey Phase 1       EN
# 2               Burkina Faso 2021 PMA Survey Phase 2       EN
# 3  The global indicator represents all women of r...       EN
# 4              Côte d'Ivoire 2020 PMA Survey Phase 1       EN

# %%
#Extracted coulmns List
Cleaned_Data.columns
# Out:
# Index(['IndicatorCode', 'Indicator', 'ParentLocationCode', 'ParentLocation',
#        'SpatialDimValueCode', 'Location', 'Period', 'Dim1', 'Dim2', 'Value',
#        'FactComments', 'Language'],
#       dtype='object')

# %%
Cleaned_Data.head(10)
# Out:
#   IndicatorCode                                          Indicator  \
# 0      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 1      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 2      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 3      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 5      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 6      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 7      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 8      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 9      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#   ParentLocationCode   ParentLocation SpatialDimValueCode  \
# 0                AFR           Africa                 UGA
# 1                AFR           Africa                 NER
# 2                AFR           Africa                 BFA
# 3                WPR  Western Pacific                 VNM
# 4                AFR           Africa                 CIV
# 5                EUR           Europe                 MDA
# 6                AFR           Africa                 ETH
# 7                AFR           Africa                 MDG
# 8                AMR         Americas                 PER
# 9                AFR           Africa                 KEN
#
#               Location     Period    Dim1         Dim2  Value  \
# 0               Uganda       2021  Female  15-49 years   65.5
# 1                Niger  2020-2021  Female  15-49 years   36.9
# 2         Burkina Faso  2020-2021  Female  15-49 years   58.2
# 3             Viet Nam  2020-2021  Female  15-49 years   72.1
# 4        Cote d'Ivoire       2020  Female  15-49 years   46.1
# 5  Republic of Moldova       2020  Female  15-49 years   59.5
# 6             Ethiopia       2020  Female  15-49 years   62.6
# 7           Madagascar       2020  Female  15-49 years   65.6
# 8                 Peru       2020  Female  15-49 years   65.9
# 9                Kenya       2020  Female  15-49 years   77.1
#
#                                         FactComments Language
# 0  The global indicator represents all women of r...       EN
# 1                      Niger 2021 PMA Survey Phase 1       EN
# 2               Burkina Faso 2021 PMA Survey Phase 2       EN
# 3  The global indicator represents all women of r...       EN
# 4              Côte d'Ivoire 2020 PMA Survey Phase 1       EN
# 5         Moldova 2020 Gender and Generations Survey       EN
# 6  The global indicator represents all women of r...       EN
# 7  The global indicator represents all women of r...       EN
# 8  The global indicator represents all women of r...       EN
# 9                      Kenya 2020 PMA Survey Phase 2       EN

# %% [markdown]
# Data Transformation-Renaming the Columns

# %%
#Renaming Colums
Cleaned_Data = Cleaned_Data.rename(columns={'Dim1':'Gender','Dim2':'Age_Group','Value':'Planning_Value_Rate','Language':'Language_Code', 'Location':'Country',
                                            'SpatialDimValueCode':'Country_Code', 'ParentLocation':'ParentLocation_Continent',
                                            'ParentLocationCode':'Patents_Continent_Code'})

# %%
Cleaned_Data.head(10)
# Out:
#   IndicatorCode                                          Indicator  \
# 0      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 1      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 2      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 3      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 5      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 6      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 7      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 8      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 9      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#   Patents_Continent_Code ParentLocation_Continent Country_Code  \
# 0                    AFR                   Africa          UGA
# 1                    AFR                   Africa          NER
# 2                    AFR                   Africa          BFA
# 3                    WPR          Western Pacific          VNM
# 4                    AFR                   Africa          CIV
# 5                    EUR                   Europe          MDA
# 6                    AFR                   Africa          ETH
# 7                    AFR                   Africa          MDG
# 8                    AMR                 Americas          PER
# 9                    AFR                   Africa          KEN
#
#                Country     Period  Gender    Age_Group  Planning_Value_Rate  \
# 0               Uganda       2021  Female  15-49 years                 65.5
# 1                Niger  2020-2021  Female  15-49 years                 36.9
# 2         Burkina Faso  2020-2021  Female  15-49 years                 58.2
# 3             Viet Nam  2020-2021  Female  15-49 years                 72.1
# 4        Cote d'Ivoire       2020  Female  15-49 years                 46.1
# 5  Republic of Moldova       2020  Female  15-49 years                 59.5
# 6             Ethiopia       2020  Female  15-49 years                 62.6
# 7           Madagascar       2020  Female  15-49 years                 65.6
# 8                 Peru       2020  Female  15-49 years                 65.9
# 9                Kenya       2020  Female  15-49 years                 77.1
#
#                                         FactComments Language_Code
# 0  The global indicator represents all women of r...            EN
# 1                      Niger 2021 PMA Survey Phase 1            EN
# 2               Burkina Faso 2021 PMA Survey Phase 2            EN
# 3  The global indicator represents all women of r...            EN
# 4              Côte d'Ivoire 2020 PMA Survey Phase 1            EN
# 5         Moldova 2020 Gender and Generations Survey            EN
# 6  The global indicator represents all women of r...            EN
# 7  The global indicator represents all women of r...            EN
# 8  The global indicator represents all women of r...            EN
# 9                      Kenya 2020 PMA Survey Phase 2            EN

# %% [markdown]
# Dealing with Null Values

# %%
#Checking the null values
Cleaned_Data.isnull()
# Out:
#      IndicatorCode  Indicator  Patents_Continent_Code  \
# 0            False      False                   False
# 1            False      False                   False
# 2            False      False                   False
# 3            False      False                   False
# 4            False      False                   False
# ..             ...        ...                     ...
# 132          False      False                   False
# 133          False      False                   False
# 134          False      False                   False
# 135          False      False                   False
# 136          False      False                   False
#
#      ParentLocation_Continent  Country_Code  Country  Period  Gender  \
# 0                       False         False    False   False   False
# 1                       False         False    False   False   False
# 2                       False         False    False   False   False
# 3                       False         False    False   False   False
# 4                       False         False    False   False   False
# ..                        ...           ...      ...     ...     ...
# 132                     False         False    False   False   False
# 133                     False         False    False   False   False
# 134                     False         False    False   False   False
# 135                     False         False    False   False   False
# 136                     False         False    False   False   False
#
#      Age_Group  Planning_Value_Rate  FactComments  Language_Code
# 0        False                False         False          False
# 1        False                False         False          False
# 2        False                False         False          False
# 3        False                False         False          False
# 4        False                False         False          False
# ..         ...                  ...           ...            ...
# 132      False                False         False          False
# 133      False                False         False          False
# 134      False                False         False          False
# 135      False                False         False          False
# 136      False                False         False          False
#
# [137 rows x 12 columns]

# %% [markdown]
# Data set doesnot Have any null values, However if we have null values we can run codes below
# 'Cleaned_Data.isnull()' # if output is true!! :
# 'Cleaned_Data[Cleaned_Data['column_Name'].isna()--1]' #for checking null values
# 'Cleaned_Data['column_Name']=Cleaned_Data['column_Name'].fillna(0)' #Rplacing null values with zero
#
# 'Cleaned_Data[Cleaned_Data['column_Name'] == 'any Null Records value/observation'] #to varify null value replacement

# %% [markdown]
# Chrecking the Duplicates

# %%
#checking duplicates
Cleaned_Data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 132    False
# 133    False
# 134    False
# 135    False
# 136    False
# Length: 137, dtype: bool

# %% [markdown]
# Data set doesnot Have any Duplicate values, However if we have duplicate values than we can run codes below
# 'Cleaned_Data.duplicated()' # if output is true!! :
# 'Cleaned_Data[Cleaned_Data['column_Name'].duplicated()--1]' #for checking duplicates values
# 'Cleaned_Data[Cleaned_Data['column_Name'].isin(['duplicate value1','duplicate value2','duplicate value3'])]'
# 'Cleaned_Data=Cleaned_Data.drop_duplicates()'

# %% [markdown]
# Data Transformation for Time period columns or Dates

# %%
#split up span in to start and end date
Cleaned_Data['Period']
# Out:
# 0           2021
# 1      2020-2021
# 2      2020-2021
# 3      2020-2021
# 4           2020
#          ...
# 132         2006
# 133         2005
# 134    2004-2005
# 135         2004
# 136         2001
# Name: Period, Length: 137, dtype: object

# %% [markdown]
# Spliting the uneven Time period columns

# %%
#Splitting years by pattern '-'
Cleaned_Data['Period'].str.split(pat='-')
# Out:
# 0            [2021]
# 1      [2020, 2021]
# 2      [2020, 2021]
# 3      [2020, 2021]
# 4            [2020]
#            ...
# 132          [2006]
# 133          [2005]
# 134    [2004, 2005]
# 135          [2004]
# 136          [2001]
# Name: Period, Length: 137, dtype: object

# %%
#checking plit where 0=starting year=LHS values
Cleaned_Data['Period'].str.split(pat='-').str[0]
# Out:
# 0      2021
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 132    2006
# 133    2005
# 134    2004
# 135    2004
# 136    2001
# Name: Period, Length: 137, dtype: object

# %%
#adding left hand values to new column name 'Starting_Year'
Cleaned_Data['Starting_Year'] = Cleaned_Data['Period'].str.split(pat='-').str[0]

# %%
#checking plit where 1=year_Ending=RHS values
Cleaned_Data['Period'].str.split(pat='-').str[1]
# Out:
# 0       NaN
# 1      2021
# 2      2021
# 3      2021
# 4       NaN
#        ...
# 132     NaN
# 133     NaN
# 134    2005
# 135     NaN
# 136     NaN
# Name: Period, Length: 137, dtype: object

# %%
##adding Right hand values to new column name 'Year_Ending'
Cleaned_Data['Year_Ending'] = Cleaned_Data['Period'].str.split(pat='-').str[1]

# %%
Cleaned_Data.head(5)
# Out:
#   IndicatorCode                                          Indicator  \
# 0      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 1      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 2      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 3      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#   Patents_Continent_Code ParentLocation_Continent Country_Code        Country  \
# 0                    AFR                   Africa          UGA         Uganda
# 1                    AFR                   Africa          NER          Niger
# 2                    AFR                   Africa          BFA   Burkina Faso
# 3                    WPR          Western Pacific          VNM       Viet Nam
# 4                    AFR                   Africa          CIV  Cote d'Ivoire
#
#       Period  Gender    Age_Group  Planning_Value_Rate  \
# 0       2021  Female  15-49 years                 65.5
# 1  2020-2021  Female  15-49 years                 36.9
# 2  2020-2021  Female  15-49 years                 58.2
# 3  2020-2021  Female  15-49 years                 72.1
# 4       2020  Female  15-49 years                 46.1
#
#                                         FactComments Language_Code  \
# 0  The global indicator represents all women of r...            EN
# 1                      Niger 2021 PMA Survey Phase 1            EN
# 2               Burkina Faso 2021 PMA Survey Phase 2            EN
# 3  The global indicator represents all women of r...            EN
# 4              Côte d'Ivoire 2020 PMA Survey Phase 1            EN
#
#   Starting_Year Year_Ending
# 0          2021         NaN
# 1          2020        2021
# 2          2020        2021
# 3          2020        2021
# 4          2020         NaN

# %% [markdown]
# checking the null values after Date columns transformation

# %%
# checking null values for column 'year_Ending'
Cleaned_Data.isnull()
# Out:
#      IndicatorCode  Indicator  Patents_Continent_Code  \
# 0            False      False                   False
# 1            False      False                   False
# 2            False      False                   False
# 3            False      False                   False
# 4            False      False                   False
# ..             ...        ...                     ...
# 132          False      False                   False
# 133          False      False                   False
# 134          False      False                   False
# 135          False      False                   False
# 136          False      False                   False
#
#      ParentLocation_Continent  Country_Code  Country  Period  Gender  \
# 0                       False         False    False   False   False
# 1                       False         False    False   False   False
# 2                       False         False    False   False   False
# 3                       False         False    False   False   False
# 4                       False         False    False   False   False
# ..                        ...           ...      ...     ...     ...
# 132                     False         False    False   False   False
# 133                     False         False    False   False   False
# 134                     False         False    False   False   False
# 135                     False         False    False   False   False
# 136                     False         False    False   False   False
#
#      Age_Group  Planning_Value_Rate  FactComments  Language_Code  \
# 0        False                False         False          False
# 1        False                False         False          False
# 2        False                False         False          False
# 3        False                False         False          False
# 4        False                False         False          False
# ..         ...                  ...           ...            ...
# 132      False                False         False          False
# 133      False                False         False          False
# 134      False                False         False          False
# 135      False                False         False          False
# 136      False                False         False          False
#
#      Starting_Year  Year_Ending
# 0            False         True
# 1            False        False
# 2            False        False
# 3            False        False
# 4            False         True
# ..             ...          ...
# 132          False         True
# 133          False         True
# 134          False        False
# 135          False         True
# 136          False         True
#
# [137 rows x 14 columns]

# %%
#checking records who is carrying null values for year_ending column
Cleaned_Data[Cleaned_Data['Year_Ending'].isna()==1]
# Out:
#     IndicatorCode                                          Indicator  \
# 0        SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4        SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 5        SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 6        SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 7        SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# ..            ...                                                ...
# 130      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 132      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 133      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 135      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 136      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#     Patents_Continent_Code ParentLocation_Continent Country_Code  \
# 0                      AFR                   Africa          UGA
# 4                      AFR                   Africa          CIV
# 5                      EUR                   Europe          MDA
# 6                      AFR                   Africa          ETH
# 7                      AFR                   Africa          MDG
# ..                     ...                      ...          ...
# 130                    WPR          Western Pacific          MHL
# 132                    EUR                   Europe          AZE
# 133                    AFR                   Africa          CPV
# 135                    EUR                   Europe          ROU
# 136                    WPR          Western Pacific          CHN
#
#                  Country Period  Gender    Age_Group  Planning_Value_Rate  \
# 0                 Uganda   2021  Female  15-49 years                 65.5
# 4          Cote d'Ivoire   2020  Female  15-49 years                 46.1
# 5    Republic of Moldova   2020  Female  15-49 years                 59.5
# 6               Ethiopia   2020  Female  15-49 years                 62.6
# 7             Madagascar   2020  Female  15-49 years                 65.6
# ..                   ...    ...     ...          ...                  ...
# 130     Marshall Islands   2007  Female  15-49 years                 80.5
# 132           Azerbaijan   2006  Female  15-49 years                 21.5
# 133           Cabo Verde   2005  Female  15-49 years                 73.2
# 135              Romania   2004  Female  15-49 years                 46.5
# 136                China   2001  Female  15-49 years                 96.6
#
#                                           FactComments Language_Code  \
# 0    The global indicator represents all women of r...            EN
# 4                Côte d'Ivoire 2020 PMA Survey Phase 1            EN
# 5           Moldova 2020 Gender and Generations Survey            EN
# 6    The global indicator represents all women of r...            EN
# 7    The global indicator represents all women of r...            EN
# ..                                                 ...           ...
# 130  The global indicator represents all women of r...            EN
# 132  The global indicator represents all women of r...            EN
# 133  The global indicator represents all women of r...            EN
# 135  The global indicator represents all women of r...            EN
# 136  The global indicator represents all women of r...            EN
#
#     Starting_Year Year_Ending
# 0            2021         NaN
# 4            2020         NaN
# 5            2020         NaN
# 6            2020         NaN
# 7            2020         NaN
# ..            ...         ...
# 130          2007         NaN
# 132          2006         NaN
# 133          2005         NaN
# 135          2004         NaN
# 136          2001         NaN
#
# [86 rows x 14 columns]

# %% [markdown]
# Replacing null values by starting years as per the descriptions

# %%
#replacing null values by zero
#Cleaned_Data['Year_Ending'] = Cleaned_Data['Year_Ending'].fillna(0)
Cleaned_Data['Year_Ending'] = Cleaned_Data['Year_Ending'].fillna(Cleaned_Data['Starting_Year'])
Cleaned_Data.head(10)
# Out:
#   IndicatorCode                                          Indicator  \
# 0      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 1      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 2      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 3      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 5      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 6      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 7      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 8      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 9      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#   Patents_Continent_Code ParentLocation_Continent Country_Code  \
# 0                    AFR                   Africa          UGA
# 1                    AFR                   Africa          NER
# 2                    AFR                   Africa          BFA
# 3                    WPR          Western Pacific          VNM
# 4                    AFR                   Africa          CIV
# 5                    EUR                   Europe          MDA
# 6                    AFR                   Africa          ETH
# 7                    AFR                   Africa          MDG
# 8                    AMR                 Americas          PER
# 9                    AFR                   Africa          KEN
#
#                Country     Period  Gender    Age_Group  Planning_Value_Rate  \
# 0               Uganda       2021  Female  15-49 years                 65.5
# 1                Niger  2020-2021  Female  15-49 years                 36.9
# 2         Burkina Faso  2020-2021  Female  15-49 years                 58.2
# 3             Viet Nam  2020-2021  Female  15-49 years                 72.1
# 4        Cote d'Ivoire       2020  Female  15-49 years                 46.1
# 5  Republic of Moldova       2020  Female  15-49 years                 59.5
# 6             Ethiopia       2020  Female  15-49 years                 62.6
# 7           Madagascar       2020  Female  15-49 years                 65.6
# 8                 Peru       2020  Female  15-49 years                 65.9
# 9                Kenya       2020  Female  15-49 years                 77.1
#
#                                         FactComments Language_Code  \
# 0  The global indicator represents all women of r...            EN
# 1                      Niger 2021 PMA Survey Phase 1            EN
# 2               Burkina Faso 2021 PMA Survey Phase 2            EN
# 3  The global indicator represents all women of r...            EN
# 4              Côte d'Ivoire 2020 PMA Survey Phase 1            EN
# 5         Moldova 2020 Gender and Generations Survey            EN
# 6  The global indicator represents all women of r...            EN
# 7  The global indicator represents all women of r...            EN
# 8  The global indicator represents all women of r...            EN
# 9                      Kenya 2020 PMA Survey Phase 2            EN
#
#   Starting_Year Year_Ending
# 0          2021        2021
# 1          2020        2021
# 2          2020        2021
# 3          2020        2021
# 4          2020        2020
# 5          2020        2020
# 6          2020        2020
# 7          2020        2020
# 8          2020        2020
# 9          2020        2020

# %%
Cleaned_Data=Cleaned_Data.drop(['Period'],axis=1)
Cleaned_Data.head(5)
# Out:
#   IndicatorCode                                          Indicator  \
# 0      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 1      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 2      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 3      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#   Patents_Continent_Code ParentLocation_Continent Country_Code        Country  \
# 0                    AFR                   Africa          UGA         Uganda
# 1                    AFR                   Africa          NER          Niger
# 2                    AFR                   Africa          BFA   Burkina Faso
# 3                    WPR          Western Pacific          VNM       Viet Nam
# 4                    AFR                   Africa          CIV  Cote d'Ivoire
#
#    Gender    Age_Group  Planning_Value_Rate  \
# 0  Female  15-49 years                 65.5
# 1  Female  15-49 years                 36.9
# 2  Female  15-49 years                 58.2
# 3  Female  15-49 years                 72.1
# 4  Female  15-49 years                 46.1
#
#                                         FactComments Language_Code  \
# 0  The global indicator represents all women of r...            EN
# 1                      Niger 2021 PMA Survey Phase 1            EN
# 2               Burkina Faso 2021 PMA Survey Phase 2            EN
# 3  The global indicator represents all women of r...            EN
# 4              Côte d'Ivoire 2020 PMA Survey Phase 1            EN
#
#   Starting_Year Year_Ending
# 0          2021        2021
# 1          2020        2021
# 2          2020        2021
# 3          2020        2021
# 4          2020        2020

# %% [markdown]
# Coinforming Null values

# %%
# Varifying null values for column 'year_Ending'
Cleaned_Data.isnull()
# Out:
#      IndicatorCode  Indicator  Patents_Continent_Code  \
# 0            False      False                   False
# 1            False      False                   False
# 2            False      False                   False
# 3            False      False                   False
# 4            False      False                   False
# ..             ...        ...                     ...
# 132          False      False                   False
# 133          False      False                   False
# 134          False      False                   False
# 135          False      False                   False
# 136          False      False                   False
#
#      ParentLocation_Continent  Country_Code  Country  Gender  Age_Group  \
# 0                       False         False    False   False      False
# 1                       False         False    False   False      False
# 2                       False         False    False   False      False
# 3                       False         False    False   False      False
# 4                       False         False    False   False      False
# ..                        ...           ...      ...     ...        ...
# 132                     False         False    False   False      False
# 133                     False         False    False   False      False
# 134                     False         False    False   False      False
# 135                     False         False    False   False      False
# 136                     False         False    False   False      False
#
#      Planning_Value_Rate  FactComments  Language_Code  Starting_Year  \
# 0                  False         False          False          False
# 1                  False         False          False          False
# 2                  False         False          False          False
# 3                  False         False          False          False
# 4                  False         False          False          False
# ..                   ...           ...            ...            ...
# 132                False         False          False          False
# 133                False         False          False          False
# 134                False         False          False          False
# 135                False         False          False          False
# 136                False         False          False          False
#
#      Year_Ending
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 132        False
# 133        False
# 134        False
# 135        False
# 136        False
#
# [137 rows x 13 columns]

# %%
# checking duplicates values for column 'year_Ending'
Cleaned_Data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 132    False
# 133    False
# 134    False
# 135    False
# 136    False
# Length: 137, dtype: bool

# %% [markdown]
# Changing the Data type

# %%
#Checking Data type
Cleaned_Data.dtypes
# Out:
# IndicatorCode                object
# Indicator                    object
# Patents_Continent_Code       object
# ParentLocation_Continent     object
# Country_Code                 object
# Country                      object
# Gender                       object
# Age_Group                    object
# Planning_Value_Rate         float64
# FactComments                 object
# Language_Code                object
# Starting_Year                object
# Year_Ending                  object
# dtype: object

# %%
#change data type
Cleaned_Data['Starting_Year'] = pd.to_numeric(Cleaned_Data['Starting_Year'], errors='coerce')
Cleaned_Data['Year_Ending'] = pd.to_numeric(Cleaned_Data['Year_Ending'], errors='coerce')
Cleaned_Data['Gender'] = Cleaned_Data['Gender'].astype('category')

# %%
Cleaned_Data.dtypes
# Out:
# IndicatorCode                 object
# Indicator                     object
# Patents_Continent_Code        object
# ParentLocation_Continent      object
# Country_Code                  object
# Country                       object
# Gender                      category
# Age_Group                     object
# Planning_Value_Rate          float64
# FactComments                  object
# Language_Code                 object
# Starting_Year                  int64
# Year_Ending                    int64
# dtype: object

# %% [markdown]
# Data Transformation

# %%
#Cleaned DataFrame
Cleaned_Data.head(10)
# Out:
#   IndicatorCode                                          Indicator  \
# 0      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 1      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 2      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 3      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 5      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 6      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 7      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 8      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 9      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#   Patents_Continent_Code ParentLocation_Continent Country_Code  \
# 0                    AFR                   Africa          UGA
# 1                    AFR                   Africa          NER
# 2                    AFR                   Africa          BFA
# 3                    WPR          Western Pacific          VNM
# 4                    AFR                   Africa          CIV
# 5                    EUR                   Europe          MDA
# 6                    AFR                   Africa          ETH
# 7                    AFR                   Africa          MDG
# 8                    AMR                 Americas          PER
# 9                    AFR                   Africa          KEN
#
#                Country  Gender    Age_Group  Planning_Value_Rate  \
# 0               Uganda  Female  15-49 years                 65.5
# 1                Niger  Female  15-49 years                 36.9
# 2         Burkina Faso  Female  15-49 years                 58.2
# 3             Viet Nam  Female  15-49 years                 72.1
# 4        Cote d'Ivoire  Female  15-49 years                 46.1
# 5  Republic of Moldova  Female  15-49 years                 59.5
# 6             Ethiopia  Female  15-49 years                 62.6
# 7           Madagascar  Female  15-49 years                 65.6
# 8                 Peru  Female  15-49 years                 65.9
# 9                Kenya  Female  15-49 years                 77.1
#
#                                         FactComments Language_Code  \
# 0  The global indicator represents all women of r...            EN
# 1                      Niger 2021 PMA Survey Phase 1            EN
# 2               Burkina Faso 2021 PMA Survey Phase 2            EN
# 3  The global indicator represents all women of r...            EN
# 4              Côte d'Ivoire 2020 PMA Survey Phase 1            EN
# 5         Moldova 2020 Gender and Generations Survey            EN
# 6  The global indicator represents all women of r...            EN
# 7  The global indicator represents all women of r...            EN
# 8  The global indicator represents all women of r...            EN
# 9                      Kenya 2020 PMA Survey Phase 2            EN
#
#    Starting_Year  Year_Ending
# 0           2021         2021
# 1           2020         2021
# 2           2020         2021
# 3           2020         2021
# 4           2020         2020
# 5           2020         2020
# 6           2020         2020
# 7           2020         2020
# 8           2020         2020
# 9           2020         2020

# %% [markdown]
# Merging Starting year and ending year column named "Year_Period"

# %%
#Create a new column by merging Starting_Year and Year_Ending
Cleaned_Data['Year_Group'] = Cleaned_Data['Starting_Year'].astype(str) + '-' + Cleaned_Data['Year_Ending'].astype(str)
Cleaned_Data.head(5)
# Out:
#   IndicatorCode                                          Indicator  \
# 0      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 1      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 2      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 3      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#   Patents_Continent_Code ParentLocation_Continent Country_Code        Country  \
# 0                    AFR                   Africa          UGA         Uganda
# 1                    AFR                   Africa          NER          Niger
# 2                    AFR                   Africa          BFA   Burkina Faso
# 3                    WPR          Western Pacific          VNM       Viet Nam
# 4                    AFR                   Africa          CIV  Cote d'Ivoire
#
#    Gender    Age_Group  Planning_Value_Rate  \
# 0  Female  15-49 years                 65.5
# 1  Female  15-49 years                 36.9
# 2  Female  15-49 years                 58.2
# 3  Female  15-49 years                 72.1
# 4  Female  15-49 years                 46.1
#
#                                         FactComments Language_Code  \
# 0  The global indicator represents all women of r...            EN
# 1                      Niger 2021 PMA Survey Phase 1            EN
# 2               Burkina Faso 2021 PMA Survey Phase 2            EN
# 3  The global indicator represents all women of r...            EN
# 4              Côte d'Ivoire 2020 PMA Survey Phase 1            EN
#
#    Starting_Year  Year_Ending Year_Group
# 0           2021         2021  2021-2021
# 1           2020         2021  2020-2021
# 2           2020         2021  2020-2021
# 3           2020         2021  2020-2021
# 4           2020         2020  2020-2020

# %% [markdown]
# Year Group column Groupped by Year Ranges as per requirements
# from,
# Ranges,
# 2003-2005,
# 2006-2008,
# 2009-2011,
# 2012-2014,
# 2015-2017,
# 2018-2020,
# 2021-2023

# %%
# Function to determine the range for each Year_Period
def get_year_range(year_Group):
    end_year = int(year_Group.split('-')[1])
    if 2003 <= end_year <= 2005:
        return '2003-2005'
    elif 2006 <= end_year <= 2008:
        return '2006-2008'
    elif 2009 <= end_year <= 2011:
        return '2009-2011'
    elif 2012 <= end_year <= 2014:
        return '2012-2014'
    elif 2015 <= end_year <= 2017:
        return '2015-2017'
    elif 2018 <= end_year <= 2020:
        return '2018-2020'
    elif 2021 <= end_year <= 2023:
        return '2021-2023'
    else:
        return 'Out of Range'

# Apply the function to Year_Period
Cleaned_Data['Year_Period_Range'] = Cleaned_Data['Year_Group'].apply(get_year_range)

# Display the DataFrame with the new Year_Range column
Cleaned_Data.head(5)
# Out:
#   IndicatorCode                                          Indicator  \
# 0      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 1      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 2      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 3      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#   Patents_Continent_Code ParentLocation_Continent Country_Code        Country  \
# 0                    AFR                   Africa          UGA         Uganda
# 1                    AFR                   Africa          NER          Niger
# 2                    AFR                   Africa          BFA   Burkina Faso
# 3                    WPR          Western Pacific          VNM       Viet Nam
# 4                    AFR                   Africa          CIV  Cote d'Ivoire
#
#    Gender    Age_Group  Planning_Value_Rate  \
# 0  Female  15-49 years                 65.5
# 1  Female  15-49 years                 36.9
# 2  Female  15-49 years                 58.2
# 3  Female  15-49 years                 72.1
# 4  Female  15-49 years                 46.1
#
#                                         FactComments Language_Code  \
# 0  The global indicator represents all women of r...            EN
# 1                      Niger 2021 PMA Survey Phase 1            EN
# 2               Burkina Faso 2021 PMA Survey Phase 2            EN
# 3  The global indicator represents all women of r...            EN
# 4              Côte d'Ivoire 2020 PMA Survey Phase 1            EN
#
#    Starting_Year  Year_Ending Year_Group Year_Period_Range
# 0           2021         2021  2021-2021         2021-2023
# 1           2020         2021  2020-2021         2021-2023
# 2           2020         2021  2020-2021         2021-2023
# 3           2020         2021  2020-2021         2021-2023
# 4           2020         2020  2020-2020         2018-2020

# %%
Cleaned_Data.dtypes
# Out:
# IndicatorCode                 object
# Indicator                     object
# Patents_Continent_Code        object
# ParentLocation_Continent      object
# Country_Code                  object
# Country                       object
# Gender                      category
# Age_Group                     object
# Planning_Value_Rate          float64
# FactComments                  object
# Language_Code                 object
# Starting_Year                  int64
# Year_Ending                    int64
# Year_Group                    object
# Year_Period_Range             object
# dtype: object

# %% [markdown]
# Cleaned Data for Family Planning

# %%
Cleaned_Data
# Out:
#     IndicatorCode                                          Indicator  \
# 0        SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 1        SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 2        SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 3        SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 4        SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# ..            ...                                                ...
# 132      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 133      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 134      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 135      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
# 136      SDGFPALL  Women of reproductive age (aged 15-49 years) w...
#
#     Patents_Continent_Code ParentLocation_Continent Country_Code  \
# 0                      AFR                   Africa          UGA
# 1                      AFR                   Africa          NER
# 2                      AFR                   Africa          BFA
# 3                      WPR          Western Pacific          VNM
# 4                      AFR                   Africa          CIV
# ..                     ...                      ...          ...
# 132                    EUR                   Europe          AZE
# 133                    AFR                   Africa          CPV
# 134                    EUR                   Europe          FRA
# 135                    EUR                   Europe          ROU
# 136                    WPR          Western Pacific          CHN
#
#            Country  Gender    Age_Group  Planning_Value_Rate  \
# 0           Uganda  Female  15-49 years                 65.5
# 1            Niger  Female  15-49 years                 36.9
# 2     Burkina Faso  Female  15-49 years                 58.2
# 3         Viet Nam  Female  15-49 years                 72.1
# 4    Cote d'Ivoire  Female  15-49 years                 46.1
# ..             ...     ...          ...                  ...
# 132     Azerbaijan  Female  15-49 years                 21.5
# 133     Cabo Verde  Female  15-49 years                 73.2
# 134         France  Female  15-49 years                 95.5
# 135        Romania  Female  15-49 years                 46.5
# 136          China  Female  15-49 years                 96.6
#
#                                           FactComments Language_Code  \
# 0    The global indicator represents all women of r...            EN
# 1                        Niger 2021 PMA Survey Phase 1            EN
# 2                 Burkina Faso 2021 PMA Survey Phase 2            EN
# 3    The global indicator represents all women of r...            EN
# 4                Côte d'Ivoire 2020 PMA Survey Phase 1            EN
# ..                                                 ...           ...
# 132  The global indicator represents all women of r...            EN
# 133  The global indicator represents all women of r...            EN
# 134  The global indicator represents all women of r...            EN
# 135  The global indicator represents all women of r...            EN
# 136  The global indicator represents all women of r...            EN
#
#      Starting_Year  Year_Ending Year_Group Year_Period_Range
# 0             2021         2021  2021-2021         2021-2023
# 1             2020         2021  2020-2021         2021-2023
# 2             2020         2021  2020-2021         2021-2023
# 3             2020         2021  2020-2021         2021-2023
# 4             2020         2020  2020-2020         2018-2020
# ..             ...          ...        ...               ...
# 132           2006         2006  2006-2006         2006-2008
# 133           2005         2005  2005-2005         2003-2005
# 134           2004         2005  2004-2005         2003-2005
# 135           2004         2004  2004-2004         2003-2005
# 136           2001         2001  2001-2001      Out of Range
#
# [137 rows x 15 columns]

# %%
# Set the path to the resources folder to exctract CSV of Cleaned Data
resources_path = "Extracted Cleaned Data File"
filename = "Cleaned_Data.csv"

# Save the Cleaned_Data DataFrame to a CSV file in the resources folder
Cleaned_Data.to_csv(f"{resources_path}/{filename}", index=False)

print(f"Cleaned_Data successfully exported to {resources_path}/{filename}")
# Out:
# Cleaned_Data successfully exported to Extracted Cleaned Data File/Cleaned_Data.csv
