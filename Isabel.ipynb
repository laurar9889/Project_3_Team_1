# %%
import pandas as pd
import os

# %%
# Load the data
Hdf = pd.read_csv('Resources/isabel.csv')

# Display the first few rows of the DataFrame to verify
Hdf.head()
# Out:
#   IndicatorCode                                          Indicator ValueType  \
# 0      WHS4_154  Antenatal care coverage - at least four visits...      text
# 1      WHS4_154  Antenatal care coverage - at least four visits...      text
# 2      WHS4_154  Antenatal care coverage - at least four visits...      text
# 3      WHS4_154  Antenatal care coverage - at least four visits...      text
# 4      WHS4_154  Antenatal care coverage - at least four visits...      text
#
#   ParentLocationCode         ParentLocation Location type SpatialDimValueCode  \
# 0                EMR  Eastern Mediterranean       Country                 SAU
# 1                AFR                 Africa       Country                 SEN
# 2                EMR  Eastern Mediterranean       Country                 TUN
# 3                EMR  Eastern Mediterranean       Country                 JOR
# 4                EMR  Eastern Mediterranean       Country                 YEM
#
#        Location Period type     Period  ...  FactValueUoM  \
# 0  Saudi Arabia        Year       2023  ...           NaN
# 1       Senegal        Year  2021-2023  ...           NaN
# 2       Tunisia        Year  2021-2023  ...           NaN
# 3        Jordan        Year  2021-2023  ...           NaN
# 4         Yemen        Year  2020-2023  ...           NaN
#
#    FactValueNumericLowPrefix  FactValueNumericLow  FactValueNumericHighPrefix  \
# 0                        NaN                  NaN                         NaN
# 1                        NaN                  NaN                         NaN
# 2                        NaN                  NaN                         NaN
# 3                        NaN                  NaN                         NaN
# 4                        NaN                  NaN                         NaN
#
#    FactValueNumericHigh  Value  FactValueTranslationID  \
# 0                   NaN   88.8                     NaN
# 1                   NaN   68.4                     NaN
# 2                   NaN     79                     NaN
# 3                   NaN   93.1                     NaN
# 4                   NaN   32.4                     NaN
#
#                                       FactComments  Language  \
# 0  Women Health and Reproductive Care Survey 2023.        EN
# 1        DHS 2023 (DHS Continuous) Key indicators.        EN
# 2                             MICS 2023 (snaphots)        EN
# 3                      PFHS 2023 (key indicators).        EN
# 4                                  MICS 2022-2023.        EN
#
#           DateModified
# 0  2024-05-13 00:00:00
# 1  2024-05-13 00:00:00
# 2  2024-05-13 00:00:00
# 3  2024-05-13 00:00:00
# 4  2024-05-13 00:00:00
#
# [5 rows x 34 columns]

# %%
Isabeldf_cleaned = Hdf[['IndicatorCode', 'Indicator', 'ParentLocation', 'Location', 'Period', 'Dim2', 'Value', 'FactComments']]

Isabeldf_cleaned.head()
# Out:
#   IndicatorCode                                          Indicator  \
# 0      WHS4_154  Antenatal care coverage - at least four visits...
# 1      WHS4_154  Antenatal care coverage - at least four visits...
# 2      WHS4_154  Antenatal care coverage - at least four visits...
# 3      WHS4_154  Antenatal care coverage - at least four visits...
# 4      WHS4_154  Antenatal care coverage - at least four visits...
#
#           ParentLocation      Location     Period  Dim2 Value  \
# 0  Eastern Mediterranean  Saudi Arabia       2023   NaN  88.8
# 1                 Africa       Senegal  2021-2023   NaN  68.4
# 2  Eastern Mediterranean       Tunisia  2021-2023   NaN    79
# 3  Eastern Mediterranean        Jordan  2021-2023   NaN  93.1
# 4  Eastern Mediterranean         Yemen  2020-2023   NaN  32.4
#
#                                       FactComments
# 0  Women Health and Reproductive Care Survey 2023.
# 1        DHS 2023 (DHS Continuous) Key indicators.
# 2                             MICS 2023 (snaphots)
# 3                      PFHS 2023 (key indicators).
# 4                                  MICS 2022-2023.

# %%
# Create a copy of the DataFrame
IsDf_cleaned = Isabeldf_cleaned.copy()
# Rename the 'Value' column to 'Adolescent birth rate (per 1000 women)'

IsDf_cleaned.rename(columns={'Value': 'Anatal_care%', 'Dim2': 'Age-group'}, inplace=True)

# %%
IsDf_cleaned.head()
# Out:
#   IndicatorCode                                          Indicator  \
# 0      WHS4_154  Antenatal care coverage - at least four visits...
# 1      WHS4_154  Antenatal care coverage - at least four visits...
# 2      WHS4_154  Antenatal care coverage - at least four visits...
# 3      WHS4_154  Antenatal care coverage - at least four visits...
# 4      WHS4_154  Antenatal care coverage - at least four visits...
#
#           ParentLocation      Location     Period  Age-group Anatal_care%  \
# 0  Eastern Mediterranean  Saudi Arabia       2023        NaN         88.8
# 1                 Africa       Senegal  2021-2023        NaN         68.4
# 2  Eastern Mediterranean       Tunisia  2021-2023        NaN           79
# 3  Eastern Mediterranean        Jordan  2021-2023        NaN         93.1
# 4  Eastern Mediterranean         Yemen  2020-2023        NaN         32.4
#
#                                       FactComments
# 0  Women Health and Reproductive Care Survey 2023.
# 1        DHS 2023 (DHS Continuous) Key indicators.
# 2                             MICS 2023 (snaphots)
# 3                      PFHS 2023 (key indicators).
# 4                                  MICS 2022-2023.

# %%
# Export the cleaned data to CSV
IsDf_cleaned.to_csv("Output/Isabel.csv", index=False)
